# %%
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt 

from multiqa_utils import eval_utils as eu

# %load_ext autoreload
# %autoreload 2

# %%
output_dir = "/scratch/ddr8143/multiqa/baseline_runs_v0/ambigqa_bm25_100.from_nq.bs_48.ws_4.t_0.s_0/reader_training/"
output_file = "26581335_reader__ambigqa_bm25_100.from_nq.bs_48.ws_4.t_0.s_0.out"
outpath = f"{output_dir}{output_file}"

# %%
reader_training_exact_match_results = eu.parse_epoch_em_from_dpr_reader_training_logs(outpath, n_gpus=4)

# %%
vals = list(reader_training_exact_match_results.items())
plt.figure(figsize=(10, 5))
plt.plot([v[0] for v in vals], [v[1] for v in vals], label="Val Exact Match")
plt.xlabel("Epoch")
plt.ylabel("Percent Exact Match")
plt.title("AmbigQA Reader Training")
plt.ylim([0, 15])
plt.show()
